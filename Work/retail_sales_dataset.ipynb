# %% [markdown]
# **Project: 1**
# Assignment for the Mini Project: Retail Sales Dataset
# Here is a structured assignment for the project. Each task is designed to test specific skills in data analytics.
# Objective:
# Analyze the retail dataset to uncover trends, insights, and correlations.
# Assignment Tasks:
#
# **1. Data Loading and Inspection**
#   1.	Load the dataset into a Pandas DataFrame.

# %%
import pandas as pd
df=pd.read_csv("/content/retail_sales_dataset.csv")

# %%
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %% [markdown]
# **2.	Display the first 10 rows of the dataset.**

# %%
df.head(10)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
# 5               6  2023-04-25     CUST006  Female   45           Beauty
# 6               7  2023-03-13     CUST007    Male   46         Clothing
# 7               8  2023-02-22     CUST008    Male   30      Electronics
# 8               9  2023-12-13     CUST009    Male   63      Electronics
# 9              10  2023-10-07     CUST010  Female   52         Clothing
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# ...

# %% [markdown]
# **3.	Print the column names and their respective data types.**

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %% [markdown]
# 4.	Check for missing values and duplicates in the dataset. How would you handle them?

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Deliverables:
# •	A brief summary of the dataset.
# •	A count of missing values and duplicate rows.

# %% [markdown]
# The dataset iam working with is called retail_sales_dataset.csv. It has been loaded into a Pandas DataFrame named df.
#
# The dataset likely contains information related to retail sales, potentially including columns like 'Transaction ID', 'Date', 'Product', 'Price', 'Customer ID', 'Store Location', and others. To get a better understanding of the dataset structure and content, consider using the following functions:
#
# df.head(10): Displays the first 10 rows of the dataset
# df.info(): Provides a summary of the dataset (number of entries, data types of each column, and memory usage)
# df.describe(): Provides descriptive statistics for numerical columns
# Count of Missing Values and Duplicate Rows
#
# The following code has already been used to identify missing values and duplicates:
#
#
# df.isnull().sum()
# df.duplicated().sum()
# Use code with caution
# df.isnull().sum(): This provides a count of missing values for each column.
# df.duplicated().sum(): This provides the total number of duplicate rows in the dataset.

# %% [markdown]
# 2. **Data** **Cleaning**

# %% [markdown]
# 1.	If there are duplicates, remove them.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicates if duplicates are there then use a function
# **drop_dupliates()**

# %% [markdown]
# 2.	Handle missing values appropriately (drop or impute them).

# %% [markdown]
# # For demonstration, I will fill numeric missing values with the mean and categorical missing values with the mode
#
# for column in df.columns:
#   if df[column].isnull().any():
#     if pd.api.types.is_numeric_dtype(df[column]):
#       df[column].fillna(df[column].mean(), inplace=True)
#     else:
#       df[column].fillna(df[column].mode()[0], inplace=True)
#
# # Verify that missing values are handled
# print(df.isnull().sum())

# %% [markdown]
# 3.	Rename the columns to more meaningful names, if necessary.

# %%
df=df.rename(columns={'Customer ID':'cust_ID'})

# %%
df
# Out:
#      Transaction ID        Date   cust_ID  Gender  Age Product Category  \
# 0                 1  2023-11-24   CUST001    Male   34           Beauty
# 1                 2  2023-02-27   CUST002  Female   26         Clothing
# 2                 3  2023-01-13   CUST003    Male   50      Electronics
# 3                 4  2023-05-21   CUST004    Male   37         Clothing
# 4                 5  2023-05-06   CUST005    Male   30           Beauty
# ..              ...         ...       ...     ...  ...              ...
# 995             996  2023-05-16   CUST996    Male   62         Clothing
# 996             997  2023-11-17   CUST997    Male   52           Beauty
# 997             998  2023-10-29   CUST998  Female   23           Beauty
# 998             999  2023-12-05   CUST999  Female   36      Electronics
# 999            1000  2023-04-12  CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 0           3              50           150
# ...

# %% [markdown]
# *   cleaned dataset

# %% [markdown]
# 1. Handling Missing Values
# Detection: Check for missing values using methods like .isnull().sum() in pandas.
# Removal: Drop rows or columns with too many missing values.
# Imputation: Fill missing values with mean, median, mode, or a specific placeholder.
# 2. Removing Duplicates
# Identifying duplicate rows using .duplicated().
# Removing duplicates with .drop_duplicates().

# %% [markdown]
# •	Explanation of how you handled missing values and duplicates.

# %% [markdown]
# 1. Handling Missing Values
# Missing values occur when data is incomplete or unavailable. They can impact data analysis and machine learning models, leading to incorrect results.
#
# Approaches to Handle Missing Values:
# Removing Missing Data (Dropping Rows or Columns)
#
# If a row or column has too many missing values, it might be best to remove it.
# This is effective when missing data is minimal, but excessive removal may lead to data loss.
# Imputation (Filling Missing Values)
#
# Mean, Median, or Mode Imputation:
# Numerical values can be replaced with the mean (average), median (middle value), or mode (most frequent value).
# Constant Value Imputation:
# Categorical values can be filled with placeholders like "Unknown" or "Not Available".
# Forward Fill (ffill) and Backward Fill (bfill):
# Missing values are filled using the previous (ffill) or next (bfill) available value.
# Prediction-Based Imputation
#
# Use machine learning models to predict missing values based on other available data.

# %% [markdown]
# 1.	Plot the distribution of the following discrete features:
# 	Quantity
#
# *   Quantity
# *   Category
# *   Region

# %%
# prompt: 1.	Plot the distribution of the following discrete features:
# o	Quantity
# o	Category
# o	Region

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset into a Pandas DataFrame.
df = pd.read_csv("/content/retail_sales_dataset.csv")

# Rename the columns to more meaningful names, if necessary.
df = df.rename(columns={'Customer ID':'cust_ID'})

# Handle missing values appropriately (drop or impute them).
for column in df.columns:
  if df[column].isnull().any():
    if pd.api.types.is_numeric_dtype(df[column]):
      df[column].fillna(df[column].mean(), inplace=True)
    else:
      df[column].fillna(df[column].mode()[0], inplace=True)

# If there are duplicates, remove them.
df.drop_duplicates(inplace=True)

# Plot the distribution of 'Quantity'
plt.figure(figsize=(8, 6))
sns.histplot(df['Quantity'], kde=True)
plt.title('Distribution of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# Plot the distribution of 'Category'
plt.figure(figsize=(10, 6))
sns.countplot(y='Product Category', data=df, order = df['Product Category'].value_counts().index)
plt.title('Distribution of Category')
plt.xlabel('Count')
plt.ylabel('Product Category')
plt.show()

# Plot the distribution of 'Region'
plt.figure(figsize=(8, 6))
sns.countplot(y='Age', data=df, order = df['Age'].value_counts().index)
plt.title('Distribution of Region')
plt.xlabel('Count')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# 2.	Identify the most frequently purchased product category.

# %%
count=df['Product Category'].value_counts().max()
category=df['Product Category'].value_counts().idxmax()
print(category ,":",count)
# Out:
# Clothing : 351

# %% [markdown]
# 3.	Find the region contributing the most to sales.

# %%
count=df['Product Category'].value_counts().max()
key=df['Gender'].value_counts().idxmax()
print(key ,":",count)
# Out:
# Female : 351

# %% [markdown]
# 1.	Convert the Order Date column to a datetime format.

# %%
# Calculate total sales for all genders
total_sales = df['Total Amount'].sum()

# Filter data for female customers
female_sales_data = df[df['Gender'] == 'Female']

# Calculate total sales for female customers
female_sales = female_sales_data['Total Amount'].sum()

# Calculate the percentage contribution of females
female_contribution_percentage = (female_sales / total_sales) * 100

# Print the result
print(f"Female contribution to total sales: {female_contribution_percentage:.2f}%")
# Out:
# Female contribution to total sales: 51.06%

# %%
import matplotlib.pyplot as plt
total_sales = df['Total Amount'].sum()
female_sales = df[df['Gender'] == 'Female']['Total Amount'].sum()
male_sales=df[df['Gender']=='Male']['Total Amount'].sum()
labels = ['Female', 'Male']
sizes = [female_sales,male_sales]
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Contribution of Female and Male to Total Sales')

plt.show()

# %%
df['order Date']=pd.to_datetime(df['Date'])
df['order Date']
# Out:
# 0     2023-11-24
# 1     2023-02-27
# 2     2023-01-13
# 3     2023-05-21
# 4     2023-05-06
#          ...
# 995   2023-05-16
# 996   2023-11-17
# 997   2023-10-29
# 998   2023-12-05
# 999   2023-04-12
# Name: order Date, Length: 1000, dtype: datetime64[ns]

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'cust_ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount',
#        'order Date'],
#       dtype='object')

# %% [markdown]
# 2.	Create new columns:
#
# *   Day of the week.
# *   Day of the month.
# *   Month
# *   Year
# *   Season (Winter, Spring, Summer, Fall).

# %%
weekDays ={
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

df['Day_of_week']=pd.to_datetime(df['order Date']).dt.dayofweek.map(weekDays)
df['Day_of_week']
# Out:
# 0         Friday
# 1         Monday
# 2         Friday
# 3         Sunday
# 4       Saturday
#          ...
# 995      Tuesday
# 996       Friday
# 997       Sunday
# 998      Tuesday
# 999    Wednesday
# Name: Day_of_week, Length: 1000, dtype: object

# %%
months={
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9:'september'  ,
    10: 'October',
    11: 'November',
    12: 'December'
}

df['day_of_month']=pd.to_datetime(df['order Date']).dt.month.map(months)
df['day_of_month']
# Out:
# 0      November
# 1      February
# 2       January
# 3           May
# 4           May
#          ...
# 995         May
# 996    November
# 997     October
# 998    December
# 999       April
# Name: day_of_month, Length: 1000, dtype: object

# %%
df['year']=pd.to_datetime(df['order Date']).dt.year
df['year']
# Out:
# 0      2023
# 1      2023
# 2      2023
# 3      2023
# 4      2023
#        ...
# 995    2023
# 996    2023
# 997    2023
# 998    2023
# 999    2023
# Name: year, Length: 1000, dtype: int32

# %%
seasons = {
    1: 'Winter',
    2: 'Winter',
    3: 'Spring',
    4: 'Spring',
    5: 'Spring',
    6: 'Summer',
    7: 'Summer',
    8: 'Summer',
    9: 'Fall',
    10: 'Fall',
    11: 'Fall',
    12: 'Winter'
}

df['season']=pd.to_datetime(df['order Date']).dt.month.map(seasons)
df['season']
# Out:
# 0        Fall
# 1      Winter
# 2      Winter
# 3      Spring
# 4      Spring
#         ...
# 995    Spring
# 996      Fall
# 997      Fall
# 998    Winter
# 999    Spring
# Name: season, Length: 1000, dtype: object

# %%
df
# Out:
#      Transaction ID        Date   cust_ID  Gender  Age Product Category  \
# 0                 1  2023-11-24   CUST001    Male   34           Beauty
# 1                 2  2023-02-27   CUST002  Female   26         Clothing
# 2                 3  2023-01-13   CUST003    Male   50      Electronics
# 3                 4  2023-05-21   CUST004    Male   37         Clothing
# 4                 5  2023-05-06   CUST005    Male   30           Beauty
# ..              ...         ...       ...     ...  ...              ...
# 995             996  2023-05-16   CUST996    Male   62         Clothing
# 996             997  2023-11-17   CUST997    Male   52           Beauty
# 997             998  2023-10-29   CUST998  Female   23           Beauty
# 998             999  2023-12-05   CUST999  Female   36      Electronics
# 999            1000  2023-04-12  CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount order Date Day_of_week  \
# ...

# %%
# prompt: 3.	Set the Order Date column as the DataFrame index.

df.set_index('order Date', inplace=True)
df
# Out:
#             Transaction ID        Date   cust_ID  Gender  Age  \
# order Date
# 2023-11-24               1  2023-11-24   CUST001    Male   34
# 2023-02-27               2  2023-02-27   CUST002  Female   26
# 2023-01-13               3  2023-01-13   CUST003    Male   50
# 2023-05-21               4  2023-05-21   CUST004    Male   37
# 2023-05-06               5  2023-05-06   CUST005    Male   30
# ...                    ...         ...       ...     ...  ...
# 2023-05-16             996  2023-05-16   CUST996    Male   62
# 2023-11-17             997  2023-11-17   CUST997    Male   52
# 2023-10-29             998  2023-10-29   CUST998  Female   23
# 2023-12-05             999  2023-12-05   CUST999  Female   36
# 2023-04-12            1000  2023-04-12  CUST1000    Male   47
#
#            Product Category  Quantity  Price per Unit  Total Amount  \
# order Date
# 2023-11-24           Beauty         3              50           150
# ...

# %% [markdown]
# 5. Correlation Analysis
#   1.	Compute the correlation matrix for numerical columns.
#   2.	Visualize the correlation matrix using a heatmap.
#   3.	Identify and discuss two key relationships from the heatmap.

# %%
# prompt: Compute the correlation matrix for numerical columns.

correlation_matrix = df.corr(numeric_only=True)
correlation_matrix
# Out:
#                 Transaction ID       Age  Quantity  Price per Unit  \
# Transaction ID        1.000000  0.065191 -0.026623       -0.060837
# Age                   0.065191  1.000000 -0.023737       -0.038423
# Quantity             -0.026623 -0.023737  1.000000        0.017501
# Price per Unit       -0.060837 -0.038423  0.017501        1.000000
# Total Amount         -0.075034 -0.060568  0.373707        0.851925
# year                 -0.010855  0.023269 -0.020324        0.020097
#
#                 Total Amount      year
# Transaction ID     -0.075034 -0.010855
# Age                -0.060568  0.023269
# Quantity            0.373707 -0.020324
# Price per Unit      0.851925  0.020097
# Total Amount        1.000000  0.024714
# year                0.024714  1.000000

# %%
corr_matrix=df.corr(numeric_only=True)
corr_matrix
# Out:
#                 Transaction ID       Age  Quantity  Price per Unit  \
# Transaction ID        1.000000  0.065191 -0.026623       -0.060837
# Age                   0.065191  1.000000 -0.023737       -0.038423
# Quantity             -0.026623 -0.023737  1.000000        0.017501
# Price per Unit       -0.060837 -0.038423  0.017501        1.000000
# Total Amount         -0.075034 -0.060568  0.373707        0.851925
# year                 -0.010855  0.023269 -0.020324        0.020097
#
#                 Total Amount      year
# Transaction ID     -0.075034 -0.010855
# Age                -0.060568  0.023269
# Quantity            0.373707 -0.020324
# Price per Unit      0.851925  0.020097
# Total Amount        1.000000  0.024714
# year                0.024714  1.000000

# %%
plt.figure(figsize=(5, 2))
sns.heatmap(correlation_matrix, annot=True, cmap="Reds", fmt=".3f")
plt.title('Correlation Matrix')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df'
# If not, replace 'df' with the actual name of your DataFrame

# Create the scatter plot using seaborn
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
sns.scatterplot(x='Quantity', y='Total Amount', data=df)
plt.title('Correlation between Quantity and Total Amount')
plt.xlabel('Quantity')
plt.ylabel('Total Amount')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Quantity', y='Total Amount', data=df, hue='Product Category')
plt.title('Correlation between Quantity and Total Amount by Product Category')
plt.xlabel('Quantity')
plt.ylabel('Total Amount')
plt.show()

# %%
correlate=df['Quantity'].corr(df['Total Amount'])
correlate
# Out:
# 0.3737070541214061

# %%
import matplotlib.pyplot as plt
category_sales = df.groupby('Product Category')['Total Amount'].sum()
labels = category_sales.index
sizes = category_sales.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Distribution of Sales by Product Category')

plt.show()

# %% [markdown]
# 1.	Write a one-page summary of key insights from the analysis

# %% [markdown]
# Retail Sales Dataset Analysis: Key Insights
#
# **Introduction**
#
# This report summarizes the key insights derived from the analysis of the retail sales dataset. The analysis aimed to uncover trends, patterns, and correlations within the data to provide a better understanding of customer behavior and sales performance.
#
# Dataset Overview
#
# The dataset contains information on retail transactions, including product details, customer demographics, purchase dates, quantities, and total amounts. The analysis focused on exploring relationships between these variables to extract meaningful insights.
#
# Data Cleaning and Preprocessing
#
# Missing values were handled by imputation, filling numerical columns with the mean and categorical columns with the mode.
# Duplicate rows were removed to ensure data integrity.
# Column names were renamed for better readability and consistency.
# The 'Order Date' column was converted to datetime format, and new columns were created for day of the week, day of the month, month, year, and season.
# Key Insights
#
# Product Category: The most frequently purchased product category is Electronics. This suggests a high demand for electronic goods among customers.
#
# Region: Male are the gender which is contributing the most to sales. This could indicate a potential target market for specific marketing campaigns.
#
# Correlation Analysis: A strong positive correlation exists between Quantity and Total Amount. This is expected as purchasing a larger quantity of items naturally leads to a higher total spending.
#
# Sales Distribution: The analysis revealed insights into the distribution of sales across different product categories, regions, and time periods. By examining these patterns, businesses can identify potential areas for improvement.
#
# No duplicates were found on the data set provided.
#
# Recommendations
#
# Focus on marketing and sales strategies for electronic goods, given their high demand.
# Explore region-specific marketing strategies or expand operations in high-performing regions.
# Consider offering promotions or bundles to encourage larger purchases and increase overall sales.
# Conduct further research to understand customer preferences and factors influencing purchasing decisions.
# Conclusion
#
# The analysis of the retail sales dataset revealed valuable insights into customer behavior, sales patterns, and key performance indicators. By leveraging these insights, businesses can make data-driven decisions to optimize their sales and marketing strategies, improve customer satisfaction, and achieve sustainable growth.

# %% [markdown]
# 2.	Highlight recommendations for improving sales based on your findings

# %% [markdown]
# Okay, here are some recommendations for improving sales based on the findings from your analysis of the retail sales dataset:
#
# Recommendations for Improving Sales
#
# 1. **Capitalize on Electronics Demand**:
#
# Targeted Marketing: Given the high demand for electronics, focus marketing efforts on this category to attract more customers.
# Product Diversification: Consider expanding the range of electronic products offered to cater to different customer preferences and needs.
# Promotional Offers: Implement strategic promotions and discounts on electronics to incentivize purchases and drive sales.
# Bundling: Offer bundled deals that combine electronics with related accessories or services to increase average order value.
# 2.** Focus on the Male Demographic:**
#
# Tailored Campaigns: Develop marketing campaigns specifically targeted towards male customers, considering their preferences and interests.
# Product Selection: Ensure product offerings align with the needs and preferences of male customers.
# Partnerships: Explore partnerships with brands or organizations that resonate with the male demographic to expand reach and engagement.
# 3.** Encourage Larger Purchases:**
#
# Volume Discounts: Offer discounts or incentives for purchasing larger quantities of items to encourage bulk buying.
# Loyalty Programs: Implement a loyalty program to reward repeat customers and encourage larger purchases over time.
# Bundling: Create attractive bundles of products that complement each other to incentivize customers to buy more items.
# 4. **Optimize Sales by Region:**
#
# Regional Analysis: Conduct a deeper analysis of sales performance by region to identify high-performing and underperforming areas.
# Targeted Strategies: Develop region-specific marketing and sales strategies based on the unique characteristics and preferences of each region.
# Inventory Management: Optimize inventory levels in each region to ensure efficient product availability and minimize stockouts.
# 5. **Enhance Customer Experience:**
#
# Personalized Recommendations: Implement a recommendation system to offer personalized product suggestions to customers based on their purchase history and browsing behavior.
# Improved Customer Service: Provide exceptional customer service to build loyalty and encourage repeat purchases.
# Seamless Checkout Process: Optimize the online and in-store checkout process to make it quick, easy, and convenient for customers.
# 6**. Leverage Data-Driven Insights:**
#
# Continuous Monitoring: Regularly track and analyze sales data to identify emerging trends, customer preferences, and areas for improvement.
# A/B Testing: Conduct A/B testing to experiment with different marketing and sales strategies to determine what works best.
# Predictive Analytics: Utilize predictive analytics to forecast future sales trends and make proactive decisions to optimize inventory and resource allocation.

# %% [markdown]
#  **2.	Highlight recommendations for improving sales based on your findings.**                                                                                                                                                                              ** Recommendations for Improving Sales**
#
# **Capitalize on Electronics Demand:**
# Targeted Marketing: Given the high demand for electronics, focus marketing efforts on this category to attract more customers.
#
# **Product Diversification:** Consider expanding the range of electronic products offered to cater to different customer preferences and needs.
#
# **Promotional Offers:** Implement strategic promotions and discounts on electronics to incentivize purchases and drive sales.
#
# **Bundling**: Offer bundled deals that combine electronics with related accessories or services to increase average order value.
#
# **Focus on the Male Demographic:**
#
# **Tailored Campaigns**: Develop marketing campaigns specifically targeted towards male customers, considering their preferences and interests.
#
# **Product Selection:** Ensure product offerings align with the needs and preferences of male customers.
#
# **Partnerships:** Explore partnerships with brands or organizations that resonate with the male demographic to expand reach and engagement.
#
# **Encourage Larger Purchases:**
#
# **Volume Discounts:**  Offer discounts or incentives for purchasing larger quantities of items to encourage bulk buying.
#
# **Loyalty Programs:** Implement a loyalty program to reward repeat customers and encourage larger purchases over time.
#
# **Bundling:** Create attractive bundles of products that complement each other to incentivize customers to buy more items.
#
# **Optimize Sales by Region:**
#
# **Regional Analysis:**  Conduct a deeper analysis of sales performance by region to identify high-performing and underperforming areas.
#
# **Targeted Strategies:** Develop region-specific marketing and sales strategies based on the unique characteristics and preferences of each region.
#
# **Inventory Management:** Optimize inventory levels in each region to ensure efficient product availability and minimize stockouts.

# %%
count = df['Product Category'].value_counts().max()
category = df['Product Category'].value_counts().idxmax()
print(category, ":", count)
# Out:
# Clothing : 351

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Product Category', data=df, order=df['Product Category'].value_counts().index)
plt.title('Distribution of Product Categories')
plt.xlabel('Number of Items Sold')
plt.ylabel('Product Category')
plt.show()
